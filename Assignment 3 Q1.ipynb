# %%
import pandas as pd
import scipy 
import numpy as np
from scipy import stats
import statsmodels.api as st
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\advay\\Downloads\\Assignment 3\\Cutlets.csv")

# %%
st.qqplot(data['Unit A'],line='q')
st.qqplot(data['Unit B'],line='q')
plt.show()

# %%
data.mean()
# Out:
# Unit A    7.019091
# Unit B    6.964297
# dtype: float64

# %%
array1=data['Unit A'].values

# %%
array2=data['Unit B'].values

# %%
    stats.ttest_ind(array1,array2)
# Out:
# Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)
